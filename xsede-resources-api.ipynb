# %%
import requests
url = 'https://info.xsede.org/wh1/rdr-db/v1/rdr/'
response = requests.get(url)
data = response.json()
data
raw = response.text

# %%
import pandas as pd

df = pd.read_json(raw)
df.to_csv('xsede-resources.csv')
df
# Out:
#                                     access_description current_statuses  \
# 0                                                 None   decommissioned
# 1                                                 None   decommissioned
# 2                                                 None   decommissioned
# 3                                                            production
# 4                                                            production
# 5                                                 None   decommissioned
# 6                                                        pre-production
# 7                                                 None   decommissioned
# 8                                                            production
# 9                                                 None   decommissioned
# 10                                                None   decommissioned
# 11                                                None   decommissioned
# 12                                                None   decommissioned
# 13                                                None
# 14                                                None   decommissioned
# 15                                                None   decommissioned
# 16                                                None   decommissioned
# 17                                                None   decommissioned
# 18                                                None   decommissioned
# 19                                                None   decommissioned
# 20                                                None   decommissioned
# 21                                                None   decommissioned
# 22                                                None   decommissioned
# 23                                                       pre-production
# 24                                                None   decommissioned
# 25                                                       decommissioned
# 26                                                None       production
# 27                                                None   decommissioned
# 28                                                None         friendly
# 29   MSS will be available in read-only mode until ...   decommissioned
# ..                                                 ...              ...
# 215                                                      decommissioned
# 216                                               None       production
# 217                                      Secure Shell.
# 218                                               None   decommissioned
# 219
# 220                                               None   decommissioned
# 221                                               None   decommissioned
# 222                                               None   decommissioned
# 223                                                          production
# 224                                               None   decommissioned
# 225                                               None   decommissioned
# 226                                                      decommissioned
# 227  directly from tape or from a front-end cache. ...   decommissioned
# 228
# 229                                                          production
# 230                                                          production
# 231
# 232
# 233
# 234                                                      decommissioned
# 235                                                          production
# 236
# 237                   Limited to Tennessee researchers       production
# 238                                                          production
# 239                                               None  post-production
# 240                                                      decommissioned
# 241                                               None       production
# 242
# 243                                               None       production
# 244                                                          production
#
#                           info_resourceid             info_siteid  \
# 0                  nstg.ornl.teragrid.org       ornl.teragrid.org
# 1                tungsten.iu.teragrid.org         iu.teragrid.org
# 2                ranger.tacc.teragrid.org       tacc.teragrid.org
# 3                Abe-QB-Grid.teragrid.org            teragrid.org
# 4        jetstream-storage.tacc.xsede.org          tacc.xsede.org
# 5                   dtf.ncsa.teragrid.org       ncsa.teragrid.org
# 6                stampede2.tacc.xsede.org          tacc.xsede.org
# 7             teradre.purdue.teragrid.org     purdue.teragrid.org
# 8                   gordon.sdsc.xsede.org          sdsc.xsede.org
# 9                  dash.sdsc.teragrid.org       sdsc.teragrid.org
# 10               lemieux.psc.teragrid.org        psc.teragrid.org
# 11               kraken.nics.teragrid.org       nics.teragrid.org
# 12                   dtf.anl.teragrid.org        anl.teragrid.org
# 13                  schooner.ou.xsede.org            ou.xsede.org
# 14               lear.purdue.teragrid.org     purdue.teragrid.org
# 15                bigben.psc.teragrid.org        psc.teragrid.org
# 16               copper.ncsa.teragrid.org       ncsa.teragrid.org
# 17             brutus.purdue.teragrid.org     purdue.teragrid.org
# 18                frost.ncar.teragrid.org       ncar.teragrid.org
# 19                    test1.xes.xsede.org           xes.xsede.org
# 20                 tape.ncsa.teragrid.org       ncsa.teragrid.org
# 21                 condor.iu.teragrid.org         iu.teragrid.org
# 22               dtf.caltech.teragrid.org    caltech.teragrid.org
# 23              bridges.gpu.psc.xsede.org       gpu.psc.xsede.org
# 24                rachel.psc.teragrid.org        psc.teragrid.org
# 25   project-work-space.ncsa.teragrid.org       ncsa.teragrid.org
# 26                wrangler.tacc.xsede.org          tacc.xsede.org
# 27             database.ncsa.teragrid.org       ncsa.teragrid.org
# 28                   usdrcg.usd.xsede.org           usd.xsede.org
# 29                 tape.ncsa.teragrid.org       ncsa.teragrid.org
# ..                                    ...                     ...
# 215    data-collections.sdsc.teragrid.org       sdsc.teragrid.org
# 216       wrangler.storage.tacc.xsede.org  storage.tacc.xsede.org
# 217                 schooner.ou.xsede.org            ou.xsede.org
# 218                   dtf.uc.teragrid.org         uc.teragrid.org
# 219                   hpc.tufts.xsede.org         tufts.xsede.org
# 220               forge.ncsa.teragrid.org       ncsa.teragrid.org
# 221            lonestar.tacc.teragrid.org       tacc.teragrid.org
# 222                quarry.iu.teragrid.org         iu.teragrid.org
# 223                  comet.sdsc.xsede.org          sdsc.xsede.org
# 224              athena.nics.teragrid.org       nics.teragrid.org
# 225                quarry.iu.teragrid.org         iu.teragrid.org
# 226                 darter.nics.xsede.org          nics.xsede.org
# 227               archive.iu.teragrid.org         iu.teragrid.org
# 228                arc-ts.umich.xsede.org         umich.xsede.org
# 229               oasis-dm.sdsc.xsede.org          sdsc.xsede.org
# 230               trestles.uark.xsede.org          uark.xsede.org
# 231                arc-ts.umich.xsede.org         umich.xsede.org
# 232                arc-ts.umich.xsede.org         umich.xsede.org
# 233                arc-ts.umich.xsede.org         umich.xsede.org
# 234                   test1.xes.xsede.org           xes.xsede.org
# 235                  usdrcg.usd.xsede.org           usd.xsede.org
# 236                arc-ts.umich.xsede.org         umich.xsede.org
# 237                 beacon.nics.xsede.org          nics.xsede.org
# 238       rmacc-summit.colorado.xsede.org      colorado.xsede.org
# 239               gordonio.sdsc.xsede.org          sdsc.xsede.org
# 240           blacklight.psc.teragrid.org        psc.teragrid.org
# 241               maverick.tacc.xsede.org          tacc.xsede.org
# 242                   hpc.tufts.xsede.org         tufts.xsede.org
# 243       rmacc-summit.colorado.xsede.org      colorado.xsede.org
# 244              comet.gpu.sdsc.xsede.org      gpu.sdsc.xsede.org
#
#        latest_status latest_status_begin latest_status_end  \
# 0     decommissioned          2011-07-31              None
# 1     decommissioned          2008-01-01              None
# 2     decommissioned          2013-02-04              None
# 3         production          2008-10-10              None
# 4         production          2016-01-01              None
# 5     decommissioned          2010-03-31              None
# 6     pre-production                None              None
# 7     decommissioned          2010-07-01              None
# 8         production          2012-02-01        2017-03-31
# 9     decommissioned          2012-02-01              None
# 10    decommissioned          2007-01-01              None
# 11    decommissioned          2014-05-01              None
# 12    decommissioned          2009-07-01              None
# 13                                  None              None
# 14    decommissioned          2008-01-01              None
# 15    decommissioned          2010-03-31              None
# 16    decommissioned          2007-09-30              None
# 17    decommissioned          2010-03-31              None
# 18    decommissioned          2011-07-31              None
# 19    decommissioned          2017-03-01              None
# 20    decommissioned          2013-09-01              None
# 21    decommissioned          2010-03-30              None
# 22    decommissioned          1005-06-17              None
# 23    pre-production                None              None
# 24    decommissioned          2008-01-01              None
# 25    decommissioned          2009-01-01              None
# 26        production          2015-02-28        2019-01-30
# 27    decommissioned          2009-01-01              None
# 28          friendly          2016-10-01              None
# 29    decommissioned          2013-09-01              None
# ..               ...                 ...               ...
# 215   decommissioned          2009-01-01              None
# 216       production          2015-02-28        2019-02-28
# 217                                 None              None
# 218   decommissioned          2009-07-01              None
# 219                                 None              None
# 220   decommissioned          2012-09-28              None
# 221   decommissioned          2010-12-13              None
# 222   decommissioned          2016-06-30              None
# 223       production          2015-04-01        2019-01-30
# 224   decommissioned          2011-07-31              None
# 225   decommissioned          2016-06-30              None
# 226   decommissioned          2016-07-01              None
# 227   decommissioned          2013-01-01              None
# 228                                 None              None
# 229       production          2012-09-11              None
# 230       production          2015-07-01        2018-07-01
# 231                                 None              None
# 232                                 None              None
# 233                                 None              None
# 234   decommissioned          2017-03-01              None
# 235       production          2006-01-01              None
# 236                                 None              None
# 237       production          2016-09-01              None
# 238       production          2017-02-06              None
# 239  post-production                None              None
# 240   decommissioned          2015-08-16              None
# 241       production          2014-03-03              None
# 242                                 None              None
# 243       production          2017-02-06              None
# 244       production          2015-04-01        2019-01-30
#
#                                       other_attributes  parent_resource  \
# 0    {'organizations': [{'organization_code': '4006...              NaN
# 1    {'organizations': [{'organization_code': '0087...              NaN
# 2    {'batch_system': 'SGE', 'supports_sensitive_da...             50.0
# 3    {'is_authorized': True, 'is_authenticated': Tr...            104.0
# 4    {'xsedenet_participant': None, 'is_authorized'...             94.0
# 5    {'organizations': [{'organization_code': '6000...              NaN
# 6    {'batch_system': 'SLURM', 'supports_sensitive_...            126.0
# 7    {'batch_system': 'Condor', 'supports_sensitive...             13.0
# 8    {'batch_system': 'Torque', 'supports_sensitive...             61.0
# 9    {'batch_system': 'Torque', 'supports_sensitive...             27.0
# 10   {'organizations': [{'organization_code': '6000...              NaN
# 11   {'organizations': [{'organization_code': 'T103...              NaN
# 12   {'organizations': [{'organization_code': '9000...              NaN
# 13   {'organizations': [{'organization_code': '0088...              NaN
# 14   {'organizations': [{'organization_code': '0018...              NaN
# 15   {'organizations': [{'organization_code': '6000...              NaN
# 16   {'batch_system': None, 'supports_sensitive_dat...              7.0
# 17   {'organizations': [{'organization_code': '0018...              NaN
# 18   {'batch_system': 'Cobalt (http://trac.mcs.anl....             31.0
# 19   {'organizations': [{'organization_code': '0000...              NaN
# 20   {'organizations': [{'organization_code': '6000...              NaN
# 21   {'batch_system': '', 'supports_sensitive_data'...             52.0
# 22   {'batch_system': '', 'supports_sensitive_data'...             53.0
# 23   {'batch_system': 'SLURM', 'supports_sensitive_...            127.0
# 24   {'batch_system': 'PBS', 'supports_sensitive_da...             22.0
# 25   {'xsedenet_participant': None, 'supports_sensi...             69.0
# 26   {'organizations': [{'organization_code': '0036...              NaN
# 27   {'organizations': [{'organization_code': '6000...              NaN
# 28   {'organizations': [{'organization_code': 'T101...              NaN
# 29   {'xsedenet_participant': None, 'is_authorized'...             76.0
# ..                                                 ...              ...
# 215  {'xsedenet_participant': None, 'is_authorized'...             73.0
# 216  {'organizations': [{'organization_code': '0036...              NaN
# 217  {'batch_system': 'SLURM', 'supports_sensitive_...            121.0
# 218  {'batch_system': '', 'supports_sensitive_data'...             25.0
# 219  {'batch_system': '', 'supports_sensitive_data'...            122.0
# 220  {'organizations': [{'organization_code': '6000...              NaN
# 221  {'batch_system': 'LSF 6.2', 'supports_sensitiv...             36.0
# 222  {'organizations': [{'organization_code': '0087...              NaN
# 223  {'batch_system': '', 'supports_sensitive_data'...             49.0
# 224  {'batch_system': 'Torque/Moab', 'supports_sens...             30.0
# 225  {'batch_system': 'N/A', 'supports_sensitive_da...             41.0
# 226  {'batch_system': 'Torque/Moab', 'supports_sens...             55.0
# 227  {'xsedenet_participant': None, 'is_authorized'...             87.0
# 228  {'batch_system': '', 'supports_sensitive_data'...            129.0
# 229  {'xsedenet_participant': None, 'is_authorized'...             86.0
# 230  {'batch_system': '', 'supports_sensitive_data'...            113.0
# 231  {'xsedenet_participant': None, 'supports_sensi...            129.0
# 232  {'xsedenet_participant': None, 'supports_sensi...            129.0
# 233  {'latitude': None, 'xsedenet_participant': Non...            129.0
# 234  {'batch_system': '', 'supports_sensitive_data'...            130.0
# 235  {'batch_system': 'SGE', 'supports_sensitive_da...            125.0
# 236  {'batch_system': '', 'supports_sensitive_data'...            129.0
# 237  {'batch_system': 'Torque/Moab', 'supports_sens...            117.0
# 238  {'batch_system': 'Slurm', 'supports_sensitive_...            131.0
# 239  {'organizations': [{'organization_code': '6000...              NaN
# 240  {'batch_system': 'PBS', 'supports_sensitive_da...             60.0
# 241  {'batch_system': 'SLURM', 'supports_sensitive_...             56.0
# 242  {'batch_system': '', 'supports_sensitive_data'...            122.0
# 243  {'organizations': [{'organization_code': '0087...              NaN
# 244  {'batch_system': '', 'supports_sensitive_data'...            128.0
#
#     project_affiliation provider_level  rdr_resource_id  rdr_type  \
# 0                 XSEDE  XSEDE Level 1                8  resource
# 1                 XSEDE  XSEDE Level 1               15  resource
# 2                 XSEDE  XSEDE Level 1           126270   compute
# 3                 XSEDE  XSEDE Level 1              458      grid
# 4                 XSEDE  XSEDE Level 1           144549   storage
# 5                 XSEDE  XSEDE Level 1               43  resource
# 6                 XSEDE  XSEDE Level 1           144584   compute
# 7                 XSEDE  XSEDE Level 1           126168   compute
# 8                 XSEDE  XSEDE Level 1           142281   compute
# 9                 XSEDE  XSEDE Level 1           142265   compute
# 10                XSEDE  XSEDE Level 1                4  resource
# 11                XSEDE  XSEDE Level 1               29  resource
# 12                XSEDE  XSEDE Level 1               32  resource
# 13                XSEDE  XSEDE Level 3              121  resource
# 14                XSEDE  XSEDE Level 1               11  resource
# 15                XSEDE  XSEDE Level 1               16  resource
# 16                XSEDE  XSEDE Level 1           125678   compute
# 17                XSEDE  XSEDE Level 1               14  resource
# 18                XSEDE  XSEDE Level 1           126030   compute
# 19                XSEDE  XSEDE Level 1              130  resource
# 20                XSEDE  XSEDE Level 1               76  resource
# 21                XSEDE  XSEDE Level 1           142308   compute
# 22                XSEDE  XSEDE Level 1           142310   compute
# 23                XSEDE  XSEDE Level 1           144585   compute
# 24                XSEDE  XSEDE Level 1           125588   compute
# 25                XSEDE  XSEDE Level 1           139848   storage
# 26                XSEDE  XSEDE Level 1               67  resource
# 27                XSEDE  XSEDE Level 1               77  resource
# 28                XSEDE  XSEDE Level 3              125  resource
# 29                XSEDE  XSEDE Level 1           141850   storage
# ..                  ...            ...              ...       ...
# 215               XSEDE  XSEDE Level 1           141477   storage
# 216               XSEDE  XSEDE Level 1               93  resource
# 217               XSEDE  XSEDE Level 3           144581   compute
# 218               XSEDE  XSEDE Level 1           142231   compute
# 219               XSEDE  XSEDE Level 3           144579   compute
# 220               XSEDE  XSEDE Level 1               34  resource
# 221               XSEDE  XSEDE Level 1           142280   compute
# 222               XSEDE  XSEDE Level 1               41  resource
# 223               XSEDE  XSEDE Level 1           142688   compute
# 224               XSEDE  XSEDE Level 1           142268   compute
# 225               XSEDE  XSEDE Level 1           126218   compute
# 226               XSEDE  XSEDE Level 1           142324   compute
# 227               XSEDE  XSEDE Level 1           139672   storage
# 228               XSEDE  XSEDE Level 3           144592   compute
# 229               XSEDE  XSEDE Level 1           142302   storage
# 230               XSEDE  XSEDE Level 3           144571   compute
# 231               XSEDE  XSEDE Level 3           144595   storage
# 232               XSEDE  XSEDE Level 3           144591   storage
# 233               XSEDE  XSEDE Level 3           144593     other
# 234               XSEDE  XSEDE Level 1           144596   compute
# 235               XSEDE  XSEDE Level 3           144583   compute
# 236               XSEDE  XSEDE Level 3           144589   compute
# 237               XSEDE  XSEDE Level 2           144575   compute
# 238               XSEDE  XSEDE Level 3           144597   compute
# 239               XSEDE  XSEDE Level 1               47  resource
# 240               XSEDE  XSEDE Level 1           142267   compute
# 241               XSEDE  XSEDE Level 1           142303   compute
# 242               XSEDE  XSEDE Level 3           144580   compute
# 243               XSEDE  XSEDE Level 3              131  resource
# 244               XSEDE  XSEDE Level 1           144586   compute
#
#                                        recommended_use  \
# 0                                                 None
# 1                                                 None
# 2    Ranger is intended for users with codes scalab...
# 3
# 4                      Storage for Jetstream Computing
# 5                                                 None
# 6    Stampede2 is intended primarily for parallel a...
# 7    The TeraDRE allows TeraGrid users to render gr...
# 8    The Gordon Compute Cluster is designed for dat...
# 9    Like its Gordon follow-on, Dash was designed f...
# 10                                                None
# 11                                                None
# 12                                                None
# 13                                                None
# 14                                                None
# 15                                                None
# 16   [DECOMM]<br />\n<strong>Status</strong>\nThis ...
# 17                                                None
# 18   The Frost Blue Gene/L system is a highly scala...
# 19                                                None
# 20                                                None
# 21
# 22
# 23
# 24   [DECOMM]<!-- please use this space for Recomme...
# 25                                                None
# 26                                                None
# 27                                                None
# 28                                                None
# 29   Archival storage managed by EMC's DiskXtender ...
# ..                                                 ...
# 215  Development (up to 5 TB), medium 5-25 TB), or ...
# 216                                               None
# 217  Non-interactive High Performance and High Thro...
# 218
# 219       Main file transfer node for compute cluster.
# 220                                               None
# 221  Lonestar is intended primarily for parallel ap...
# 222                                               None
# 223  Comet is designed to provide cyberinfrastructu...
# 224  Athena is intended for moderate to highly scal...
# 225  The Quarry Gateway Hosting System at Indiana U...
# 226  Darter is intended for highly scalable paralle...
# 227  Archival storage under control of the HPSS (Hi...
# 228
# 229  High-capacity, high-performance, short- to med...
# 230  Trestles is designed to enable modest-scale re...
# 231  Support for multiple online data ingest and da...
# 232  OSiRIS will use commercial off-the-shelf hardw...
# 233  Big Data workflows in the Hadoop/Spark ecosystem.
# 234
# 235
# 236
# 237  Beacon system can be used to port and optimize...
# 238      Parallel and high-throughput serial HPC jobs.
# 239                                               None
# 240  Blacklight is intended for applications that r...
# 241  Maverick is intended primarily for interactive...
# 242       Large memory interactive and batch computes.
# 243                                               None
# 244  GPUs are a specialized resource that performs ...
#
#                                   resource_description  \
# 0    The ORNL NSTG cluster has 28 nodes, 16 of whic...
# 1    The IU AVIDD IA-32 cluster has 192 compute nod...
# 2    The Ranger Sun Constellation Cluster is config...
# 3    NCSA/LONI Dell PowerEdge Linux Clusters (Abe/Q...
# 4                                                 None
# 5    NCSA       's IA-64 TeraGrid Linux Cluster con...
# 6    The new Stampede2 Dell Knights Landing (KNL) C...
# 7    The Purdue TeraDRE is a high-throughput visual...
# 8    The Gordon Compute Cluster is an Appro-integra...
# 9    Dash is a cluster from Appro with 64 compute n...
# 10   Lemieux comprises 610 Compaq Alphaserver ES45 ...
# 11   The Kraken system is a Cray XT5 with 9,408\r\n...
# 12   The IA-64 TeraGrid Linux Cluster at UC/ANL con...
# 13   University of Oklahoma HPC cluster schooner.os...
# 14   The Lear Cluster consists of 512 dual-CPU Dell...
# 15   BigBen is a Cray XT3 MPP system with 2068 2.6-...
# 16   The pSeries 690 is a symmetric multiprocessor ...
# 17   These resources consist of an SGI 450 (brutus....
# 18   Frost is a four-rack, Blue Gene/L system with ...
# 19        Resource Used for Testing XSEDE Capabilities
# 20                                                None
# 21                                           Condor IU
# 22                                        DTF Cal Tech
# 23   Bridges GPU - 16 GPU nodes, each with 2 NVIDIA...
# 24   Rachel is a loosely-coupled pair of SMP machin...
# 25                                                None
# 26   The Wrangler Data Analytics system is designed...
# 27                                                None
# 28
# 29                                                None
# ..                                                 ...
# 215                                               None
# 216  Storage allocations on this resource will be g...
# 217  346 TFLOPs, has some condominium including old...
# 218  The IA-64 TeraGrid Linux Cluster at UC/ANL con...
# 219       Main file transfer node for compute cluster.
# 220  Forge consists of 36 Dell PowerEdge C6145 quad...
# 221  The Lonestar Dell PowerEdge Linux Cluster is c...
# 222  The system consists of multiple Intel-based He...
# 223  Comet will be a 2.0 Petaflop (PF) Dell integra...
# 224  The Athena system is a Cray XT4 with 4512 comp...
# 225  The system consists of multiple Intel-based He...
# 226  Darter is a Cray XC30 (Cascade) supercomputer ...
# 227                                               None
# 228  The ConFlux cluster will be built with ~43 IBM...
# 229                                               None
# 230  Trestles consists of 256 compute nodes, with a...
# 231                                               None
# 232                                               None
# 233  The Data Science Platform is an upgraded Hadoo...
# 234                                         XSEDE Test
# 235
# 236  The Armis HPC cluster, in conjunction with Tur...
# 237  Beacon is an energy efficient cluster that uti...
# 238
# 239  There are 64 I/O nodes in the Gordon compute c...
# 240  Blacklight is an SGI UV 1000cc-NUMA shared-mem...
# 241  The new Maverick HP/NVIDIA Interactive Visuali...
# 242             Large memory node for compute cluster.
# 243  RMACC-Summit is a heterogeneous HPC cluster th...
# 244  Comet has 36 general purpose GPU nodes, with 2...
#
#                              resource_descriptive_name  \
# 0                       ORNL Intel Xeon Cluster (NSTG)
# 1              NCSA Xeon Linux Supercluster (Tungsten)
# 2              TACC Sun Constellation Cluster (Ranger)
# 3    NCSA/LONI Dell PowerEdge Linux Clusters (Abe/Q...
# 4                  IU/TACC Storage (Jetstream Storage)
# 5                                             NCSA DTF
# 6    TACC Dell/Intel Knight's Landing System (Stamp...
# 7    Purdue Distributed Rendering Environment (Tera...
# 8    SDSC Appro with Intel Sandy Bridge Cluster (Go...
# 9           SDSC Appro Flash Disk, vSMP Cluster (Dash)
# 10                                            PSC TCS1
# 11                              NICS Cray XT5 (Kraken)
# 12                    UChicago/Argonne compute cluster
# 13                                            Schooner
# 14                   Purdue EM64T Linux Cluster (Lear)
# 15                                   PSC XT3 (Big Ben)
# 16                              NCSA IBM p690 (Copper)
# 17        Purdue FPGA Prototyping Environment (Brutus)
# 18                          NCAR IBM Blue Gene (Frost)
# 19                                 XSEDE Test Resource
# 20                                   NCSA Tape Storage
# 21   Indiana University RenderPortal/Windows Condor...
# 22                                        Cal Tech DTF
# 23                       PSC Bridges GPU (Bridges GPU)
# 24                              PSC HP Marvel (Rachel)
# 25                    NCSA Project Work Space Per Host
# 26               TACC Data Analytics System (Wrangler)
# 27                                       NCSA Database
# 28   University of South Dakota Research Computing ...
# 29                                   NCSA Tape Storage
# ..                                                 ...
# 215                        SDSC Collections Disk Space
# 216          TACC Long-term Storage (Wrangler Storage)
# 217  U Oklahoma Dell PowerEdge R430/R730 cluster wi...
# 218                                 IA-64 Cluster Test
# 219  Tufts University High Performance Compute (HPC...
# 220    NCSA Dell with NVIDIA Fermi GPU Cluster (Forge)
# 221       TACC Dell PowerEdge Linux Cluster (Lonestar)
# 222  Indiana University Gateway/Web Service Hosting...
# 223  SDSC Dell Cluster with Intel Haswell Processor...
# 224                             NICS Cray XT4 (Athena)
# 225  Indiana University Gateway/Web Service Hosting...
# 226                            NICS Cray XC30 - Darter
# 227        Indiana University DC-WAN Lustre Filesystem
# 228             ConFlux - Data Driven Physics Platform
# 229         SDSC Medium-term disk storage (Data Oasis)
# 230    University of Arkansas/AHPCC Cluster (Trestles)
# 231                               YBRC - Data Services
# 232      OSiRIS - Open Storage Research Infrastructure
# 233                     Flux Hadoop - Big Data Cluster
# 234                        Compute XSEDE Test Resource
# 235      University of South Dakota Legacy HPC cluster
# 236                 ARMIS - Cluster for PHI/HIPAA Data
# 237                                     Beacon cluster
# 238                                       RMACC-Summit
# 239  SDSC Appro with Intel Flash I/O Nodes (Gordon ...
# 240                      PSC SGI Altix UV (Blacklight)
# 241  HP/NVIDIA Interactive Visualization and Data A...
# 242  Tufts University High Performance Compute (HPC...
# 243     RMACC Heterogeneous Compute Cluster ("Summit")
# 244                   SDSC Comet GPU Nodes (Comet GPU)
#
#                                        resource_status              updated_at
# 0    {'decommissioned_begin_date': '2011-07-31', 'd...                     NaT
# 1    {'decommissioned_begin_date': '2008-01-01', 'd...                     NaT
# 2    {'decommissioned_begin_date': '2013-02-04', 'd...                     NaT
# 3    {'decommissioned_begin_date': None, 'decommiss...                     NaT
# 4    {'decommissioned_begin_date': None, 'decommiss... 2016-06-06 18:53:16.866
# 5    {'decommissioned_begin_date': '2010-03-31', 'd...                     NaT
# 6    {'decommissioned_begin_date': None, 'decommiss... 2017-03-13 14:33:33.854
# 7    {'decommissioned_begin_date': '2010-07-01', 'd...                     NaT
# 8    {'decommissioned_begin_date': None, 'decommiss... 2017-02-15 01:43:48.352
# 9    {'decommissioned_begin_date': '2012-02-01', 'd...                     NaT
# 10   {'decommissioned_begin_date': '2007-01-01', 'd...                     NaT
# 11   {'decommissioned_begin_date': '2014-05-01', 'd...                     NaT
# 12   {'decommissioned_begin_date': '2009-07-01', 'd...                     NaT
# 13   {'decommissioned_begin_date': None, 'decommiss... 2016-10-30 17:46:12.328
# 14   {'decommissioned_begin_date': '2008-01-01', 'd...                     NaT
# 15   {'decommissioned_begin_date': '2010-03-31', 'd...                     NaT
# 16   {'decommissioned_begin_date': '2007-09-30', 'd...                     NaT
# 17   {'decommissioned_begin_date': '2010-03-31', 'd...                     NaT
# 18   {'decommissioned_begin_date': '2011-07-31', 'd...                     NaT
# 19   {'decommissioned_begin_date': '2017-03-01', 'd... 2017-03-22 21:10:58.782
# 20   {'decommissioned_begin_date': '2013-09-01', 'd...                     NaT
# 21   {'decommissioned_begin_date': '2010-03-30', 'd...                     NaT
# 22   {'decommissioned_begin_date': '1005-06-17', 'd...                     NaT
# 23   {'decommissioned_begin_date': '2019-11-30', 'd... 2017-03-16 13:30:24.321
# 24   {'decommissioned_begin_date': '2008-01-01', 'd...                     NaT
# 25   {'decommissioned_begin_date': '2009-01-01', 'd...                     NaT
# 26   {'decommissioned_begin_date': '2019-01-31', 'd... 2016-04-18 20:36:58.133
# 27   {'decommissioned_begin_date': '2009-01-01', 'd...                     NaT
# 28   {'decommissioned_begin_date': None, 'decommiss... 2017-01-27 17:22:32.268
# 29   {'decommissioned_begin_date': '2013-09-01', 'd...                     NaT
# ..                                                 ...                     ...
# 215  {'decommissioned_begin_date': '2009-01-01', 'd...                     NaT
# 216  {'decommissioned_begin_date': None, 'decommiss... 2016-04-18 16:06:43.591
# 217  {'decommissioned_begin_date': None, 'decommiss... 2016-11-20 18:13:26.424
# 218  {'decommissioned_begin_date': '2009-07-01', 'd...                     NaT
# 219  {'decommissioned_begin_date': None, 'decommiss... 2016-11-10 19:58:29.232
# 220  {'decommissioned_begin_date': '2012-09-28', 'd...                     NaT
# 221  {'decommissioned_begin_date': '2010-12-13', 'd...                     NaT
# 222  {'decommissioned_begin_date': '2016-06-30', 'd...                     NaT
# 223  {'decommissioned_begin_date': '2019-01-31', 'd... 2016-05-19 20:18:02.880
# 224  {'decommissioned_begin_date': '2011-07-31', 'd...                     NaT
# 225  {'decommissioned_begin_date': '2016-06-30', 'd...                     NaT
# 226  {'decommissioned_begin_date': '2016-07-01', 'd... 2016-09-12 19:07:56.951
# 227  {'decommissioned_begin_date': '2013-01-01', 'd...                     NaT
# 228  {'decommissioned_begin_date': None, 'decommiss... 2017-03-17 20:46:15.823
# 229  {'decommissioned_begin_date': None, 'decommiss...                     NaT
# 230  {'decommissioned_begin_date': None, 'decommiss... 2016-09-13 10:48:41.839
# 231  {'decommissioned_begin_date': None, 'decommiss... 2017-03-17 20:50:19.697
# 232  {'decommissioned_begin_date': None, 'decommiss... 2017-03-17 20:44:28.741
# 233  {'decommissioned_begin_date': None, 'decommiss... 2017-03-17 20:47:27.749
# 234  {'decommissioned_begin_date': '2017-03-01', 'd... 2017-03-22 21:10:59.924
# 235  {'decommissioned_begin_date': None, 'decommiss... 2017-01-27 17:27:48.317
# 236  {'decommissioned_begin_date': None, 'decommiss... 2017-03-17 20:43:11.988
# 237  {'decommissioned_begin_date': None, 'decommiss... 2016-10-19 21:03:31.721
# 238  {'decommissioned_begin_date': None, 'decommiss... 2017-03-28 20:19:51.007
# 239  {'decommissioned_begin_date': '2017-04-01', 'd... 2017-02-15 01:43:12.277
# 240  {'decommissioned_begin_date': '2015-08-16', 'd... 2016-05-27 18:16:21.524
# 241  {'decommissioned_begin_date': None, 'decommiss...                     NaT
# 242  {'decommissioned_begin_date': None, 'decommiss... 2016-11-10 20:04:41.994
# 243  {'decommissioned_begin_date': None, 'decommiss... 2017-03-28 20:08:09.017
# 244  {'decommissioned_begin_date': None, 'decommiss... 2017-03-15 20:36:57.488
#
# [245 rows x 18 columns]

# %%
a = df[df['current_statuses']=='production']
b = a[a['provider_level']=='XSEDE Level 1']
b[['resource_descriptive_name','rdr_type','recommended_use','resource_description','other_attributes','updated_at','rdr_resource_id']].sort_values(['rdr_type','resource_descriptive_name'])
# Out:
#                              resource_descriptive_name  rdr_type  \
# 214  HP/NVIDIA Interactive Visualization and Data A...   compute
# 33                                 IU/TACC (Jetstream)   compute
# 134                            Open Science Grid (OSG)   compute
# 109             PSC Large Memory Nodes (Bridges Large)   compute
# 90                        PSC Regular Memory (Bridges)   compute
# 5    SDSC Appro with Intel Sandy Bridge Cluster (Go...   compute
# 17                    SDSC Comet GPU Nodes (Comet GPU)   compute
# 229  SDSC Dell Cluster with Intel Haswell Processor...   compute
# 119              TACC Data Analytics System (Wrangler)   compute
# 87   TACC Dell PowerEdge C8220 Cluster with Intel X...   compute
# 2    NCSA/LONI Dell PowerEdge Linux Clusters (Abe/Q...      grid
# 120                                        Stand Alone      grid
# 140                       TeraGrid Wide Roaming Access      grid
# 88                            XSEDE Staff Storage Grid      grid
# 198                    FutureGrid Testbed (FutureGrid)     other
# 104                   SDSC Comet GPU Nodes (Comet GPU)     other
# 69                XSEDE Extended Collaborative Support     other
# 201  HP/NVIDIA Interactive Visualization and Data A...  resource
# 203                                IU/TACC (Jetstream)  resource
# 127                IU/TACC Storage (Jetstream Storage)  resource
# 80                             Open Science Grid (OSG)  resource
# 185                        PSC Storage (Bridges Pylon)  resource
# 39   SDSC Appro with Intel Sandy Bridge Cluster (Go...  resource
# 71                    SDSC Comet GPU Nodes (Comet GPU)  resource
# 204  SDSC Dell Cluster with Intel Haswell Processor...  resource
# 82          SDSC Medium-term disk storage (Data Oasis)  resource
# 97                                         Stand Alone  resource
# 218              TACC Data Analytics System (Wrangler)  resource
# 61   TACC Dell PowerEdge C8220 Cluster with Intel X...  resource
# 224          TACC Long-term Storage (Wrangler Storage)  resource
# 143       TACC Long-term tape Archival Storage (Ranch)  resource
# 70                        TeraGrid Wide Roaming Access  resource
# 137               XSEDE Extended Collaborative Support  resource
# 55                            XSEDE Staff Storage Grid  resource
# 1                  IU/TACC Storage (Jetstream Storage)   storage
# 220       PSC Persistent disk storage (Data SuperCell)   storage
# 102                        PSC Storage (Bridges Pylon)   storage
# 74          SDSC Medium-term disk storage (Data Oasis)   storage
# 72           TACC Long-term Storage (Wrangler Storage)   storage
# 223       TACC Long-term tape Archival Storage (Ranch)   storage
# 184                      XSEDE-Wide File System (XWFS)   storage
#
#                                        recommended_use  \
# 214  Maverick is intended primarily for interactive...
# 33   For the researcher needing a handful of cores ...
# 134  High throughput jobs using a single core, or a...
# 109  Extreme Shared Memory (ESM) nodes will serve t...
# 90   Regular Shared Memory nodes will provide subst...
# 5    The Gordon Compute Cluster is designed for dat...
# 17   GPUs are a specialized resource that performs ...
# 229  Comet is designed to provide cyberinfrastructu...
# 119  For research projects previously limited by I/...
# 87   Stampede is intended primarily for parallel ap...
# 2
# 120
# 140
# 88
# 198
# 104  GPUs are a specialized resource that performs ...
# 69
# 201                                               None
# 203                                               None
# 127                                               None
# 80                                                None
# 185                                               None
# 39                                                None
# 71                                                None
# 204                                               None
# 82                                                None
# 97                                                None
# 218                                               None
# 61                                                None
# 224                                               None
# 143                                               None
# 70                                                None
# 137                                               None
# 55                                                None
# 1                      Storage for Jetstream Computing
# 220                         PSC's file archival system
# 102  The Pylon file system is a persistent file sys...
# 74   High-capacity, high-performance, short- to med...
# 72   Mid-term and long-term preservation of results...
# 223  TACC's High Performance Computing systems are ...
# 184        shared, distributed data storage and access
#
#                                   resource_description  \
# 214  The new Maverick HP/NVIDIA Interactive Visuali...
# 33   Jetstream is a user-friendly cloud environment...
# 134  A virtual HTCondor pool made up of resources f...
# 109  Two node types comprise Bridges' large memory ...
# 90   Regular Shared Memory nodes each consist of tw...
# 5    The Gordon Compute Cluster is an Appro-integra...
# 17   Comet has 36 general purpose GPU nodes, with 2...
# 229  Comet will be a 2.0 Petaflop (PF) Dell integra...
# 119  The Wrangler Data Analytics system is designed...
# 87   The new Stampede Dell PowerEdge C8220 Cluster ...
# 2    NCSA/LONI Dell PowerEdge Linux Clusters (Abe/Q...
# 120                                        Stand Alone
# 140                       TeraGrid Wide Roaming Access
# 88                            XSEDE Staff Storage Grid
# 198                    FutureGrid Testbed (FutureGrid)
# 104  Comet has 36 general purpose GPU nodes, with 2...
# 69                XSEDE Extended Collaborative Support
# 201  The new Maverick HP/NVIDIA Interactive Visuali...
# 203  Jetstream is a user-friendly cloud environment...
# 127           Storage for use with Jetstream Computing
# 80   A virtual HTCondor pool made up of resources f...
# 185                       Storage for Bridges Projects
# 39   The Gordon Compute Cluster is an Appro-integra...
# 71   Comet has 36 general purpose GPU nodes, with 2...
# 204  Comet is a 2.0 Petaflop (PF) Dell integrated c...
# 82
# 97                                                None
# 218  The Wrangler Data Analytics system is designed...
# 61   The new Stampede Dell PowerEdge C8220 Cluster ...
# 224  Storage allocations on this resource will be g...
# 143
# 70
# 137
# 55
# 1                                                 None
# 220                                               None
# 102                                               None
# 74                                                None
# 72                                                None
# 223                                               None
# 184                                               None
#
#                                       other_attributes  \
# 214  {'storage_network': 'Mellanox FDR InfiniBand',...
# 33   {'storage_network': '', 'parallel_file_system'...
# 134  {'storage_network': 'None', 'parallel_file_sys...
# 109  {'storage_network': '', 'parallel_file_system'...
# 90   {'storage_network': '', 'parallel_file_system'...
# 5    {'storage_network': '64 QDR InfiniBand to I/O ...
# 17   {'storage_network': '', 'parallel_file_system'...
# 229  {'storage_network': 'FDR InfiniBand/40GigE', '...
# 119  {'storage_network': '', 'parallel_file_system'...
# 87   {'storage_network': 'FDR InfiniBand', 'paralle...
# 2    {'user_guide_url': '', 'is_publicly_available'...
# 120  {'user_guide_url': '', 'resources_in_grid': []...
# 140  {'user_guide_url': '', 'is_publicly_available'...
# 88   {'user_guide_url': '', 'is_publicly_available'...
# 198  {'latitude': None, 'user_guide_url': '', 'long...
# 104  {'user_guide_url': 'https://portal.xsede.org/s...
# 69   {'latitude': None, 'user_guide_url': '', 'long...
# 201  {'xsede_services_only': False, 'organizations'...
# 203  {'xsede_services_only': False, 'organizations'...
# 127  {'xsede_services_only': False, 'organizations'...
# 80   {'xsede_services_only': False, 'organizations'...
# 185  {'xsede_services_only': False, 'organizations'...
# 39   {'xsede_services_only': False, 'organizations'...
# 71   {'xsede_services_only': False, 'organizations'...
# 204  {'xsede_services_only': False, 'organizations'...
# 82   {'xsede_services_only': False, 'organizations'...
# 97   {'xsede_services_only': False, 'organizations'...
# 218  {'xsede_services_only': False, 'organizations'...
# 61   {'xsede_services_only': False, 'organizations'...
# 224  {'xsede_services_only': False, 'organizations'...
# 143  {'xsede_services_only': False, 'organizations'...
# 70   {'xsede_services_only': True, 'organizations':...
# 137  {'xsede_services_only': True, 'organizations':...
# 55   {'xsede_services_only': True, 'organizations':...
# 1    {'user_guide_url': '', 'longitude': None, 'is_...
# 220  {'user_guide_url': 'https://portal.xsede.org/p...
# 102  {'user_guide_url': 'https://portal.xsede.org/p...
# 74   {'user_guide_url': 'https://portal.xsede.org/s...
# 72   {'user_guide_url': 'http://portal.xsede.org/ta...
# 223  {'user_guide_url': 'https://portal.xsede.org/t...
# 184  {'user_guide_url': 'https://portal.xsede.org/x...
#
#                  updated_at  rdr_resource_id
# 214                     NaT           142303
# 33  2016-06-22 15:27:04.326           144545
# 134 2016-06-06 17:02:11.172           142288
# 109 2016-09-12 16:45:43.649           144547
# 90  2016-09-12 16:47:20.423           144546
# 5   2017-02-15 01:43:48.352           142281
# 17  2017-03-15 20:36:57.488           144586
# 229 2016-05-19 20:18:02.880           142688
# 119 2016-04-18 18:02:21.639           142689
# 87  2017-01-12 15:43:37.495           142291
# 2                       NaT              458
# 120                     NaT           142322
# 140                     NaT           142227
# 88                      NaT           142320
# 198                     NaT           142313
# 104 2017-03-15 20:22:07.363           144587
# 69                      NaT           142312
# 201 2016-04-18 20:42:48.667               56
# 203 2016-05-17 18:54:59.989               68
# 127 2016-09-01 13:20:44.001               94
# 80  2016-05-11 04:05:58.169               48
# 185 2017-02-14 18:48:28.542               95
# 39  2017-02-15 01:43:47.745               61
# 71  2017-03-15 18:38:50.564              128
# 204 2016-05-19 00:06:12.305               49
# 82                      NaT               86
# 97                      NaT              106
# 218 2016-04-18 20:36:58.133               67
# 61  2017-01-11 14:12:03.328               64
# 224 2016-04-18 16:06:43.591               93
# 143 2016-04-18 16:10:26.242               90
# 70  2016-07-27 12:28:29.363              103
# 137 2016-07-27 12:52:54.028               96
# 55  2016-07-27 12:29:32.183              107
# 1   2016-06-06 18:53:16.866           144549
# 220                     NaT           142290
# 102 2016-11-08 22:01:34.211           144548
# 74                      NaT           142302
# 72                      NaT           142690
# 223                     NaT           142293
# 184                     NaT           142301
